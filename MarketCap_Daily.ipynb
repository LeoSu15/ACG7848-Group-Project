# %%
pip install sanpy
# Out:
# Requirement already satisfied: sanpy in ./opt/anaconda3/lib/python3.8/site-packages (0.8.6)
# Requirement already satisfied: requests in ./opt/anaconda3/lib/python3.8/site-packages (from sanpy) (2.24.0)
# Requirement already satisfied: setuptools in ./opt/anaconda3/lib/python3.8/site-packages (from sanpy) (50.3.1.post20201107)
# Requirement already satisfied: pandas in ./opt/anaconda3/lib/python3.8/site-packages (from sanpy) (1.1.3)
# Requirement already satisfied: iso8601 in ./opt/anaconda3/lib/python3.8/site-packages (from sanpy) (0.1.14)
# Requirement already satisfied: idna<3,>=2.5 in ./opt/anaconda3/lib/python3.8/site-packages (from requests->sanpy) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in ./opt/anaconda3/lib/python3.8/site-packages (from requests->sanpy) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in ./opt/anaconda3/lib/python3.8/site-packages (from requests->sanpy) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in ./opt/anaconda3/lib/python3.8/site-packages (from requests->sanpy) (3.0.4)
# Requirement already satisfied: pytz>=2017.2 in ./opt/anaconda3/lib/python3.8/site-packages (from pandas->sanpy) (2020.1)
# Requirement already satisfied: numpy>=1.15.4 in ./opt/anaconda3/lib/python3.8/site-packages (from pandas->sanpy) (1.19.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in ./opt/anaconda3/lib/python3.8/site-packages (from pandas->sanpy) (2.8.1)
# Requirement already satisfied: six>=1.5 in ./opt/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas->sanpy) (1.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
#API key - qovlkte53ks5zjha_jcn4x4363pnaroe2
from san import *
import san
from decimal import Decimal
import pandas as pd
import datetime

# %%
import san
san.ApiConfig.api_key = 'qovlkte53ks5zjha_jcn4x4363pnaroe2'
san.get("projects/all")
# Out:
#            marketSegment             name             slug ticker  \
# 0               Platform   Color Platform   color-platform    CLR
# 1     Blockchain Network          Enecuum          enecuum    ENQ
# 2       Interoperability           Cosmos           cosmos   ATOM
# 3               Ethereum         ZeuxCoin         zeuxcoin    ZUC
# 4                 Gaming             Seed             seed   SEED
# ...                  ...              ...              ...    ...
# 1939            Polkadot            Crust            crust    CRU
# 1940            Ethereum  PieDAO DOUGH v2  piedao-dough-v2  DOUGH
# 1941                DeFi         SmartKey         smartkey   SKEY
# 1942             Privacy             Firo            zcoin    XZC
# 1943           Financial  Crypto.com Coin  crypto-com-coin    CRO
#
#             totalSupply
# 0             350000000
# 1         193716760.116
# 2      268426508.255299
# 3             750000000
# 4                  None
# ...                 ...
# 1939            2000010
# 1940  76629009.02192521
# 1941                  0
# 1942           21400000
# 1943        30263013692
#
# [1944 rows x 5 columns]

# %%
# Getting all slugs/tickers/names/marketsegment/supply and dropping all with missing or 0 supply
data = san.get("projects/all")
data = data.dropna()
data['totalSupply'] = data['totalSupply'].astype(float)
data = data[data['totalSupply'] != 0]

# %%
# Limiting only to Cryptocurrency
crypto = data[data["marketSegment"] == "Cryptocurrency"]
crypto = crypto.sort_values(by = ["totalSupply"], ascending = False)
crypto
# Out:
#        marketSegment              name              slug ticker   totalSupply
# 1749  Cryptocurrency          Dimecoin          dimecoin   DIME  5.559981e+11
# 1181  Cryptocurrency          Mooncoin          mooncoin   MOON  2.274909e+11
# 1855  Cryptocurrency       NewYorkCoin       newyorkcoin    NYC  1.437611e+11
# 1708  Cryptocurrency          Dogecoin          dogecoin   DOGE  1.291688e+11
# 1770  Cryptocurrency  eXPerience Chain  experience-chain    XPC  1.132155e+11
# ...              ...               ...               ...    ...           ...
# 1819  Cryptocurrency   Bitcoin Rhodium   bitcoin-rhodium    XRC  1.316162e+06
# 1105  Cryptocurrency    White Standard    white-standard    WSD  4.394020e+05
# 1443  Cryptocurrency      ParallelCoin      parallelcoin    DUO  3.147186e+05
# 347   Cryptocurrency        Unobtanium        unobtanium    UNO  2.033284e+05
# 1762  Cryptocurrency            Amoveo            amoveo    VEO  6.983818e+04
#
# [139 rows x 5 columns]

# %%
def metriclist(slug):
    metric = "marketcap_usd" 
    fullname = metric + "/" + slug 
    metrics = san.get(
    fullname,
    from_date="2018-04-01",
    to_date="2021-04-01",
    interval="1d"
    )
    newname = slug+"_"+metric
    finaldf = metrics.rename(columns={"value": newname})
    return(finaldf)

# %%
# Change metric and slug fullname = metric + slug
# Running through all cryptocurrencies and adding price and daily returns
count = 0
metric_df = pd.DataFrame()
for i in crypto['slug'].tolist():
    holddf = metriclist(i)
    if count == 0:
        metric_df = holddf
    else:
        metric_df = pd.merge(metric_df, holddf, how = "left", on = "datetime")
    count = count+1

# %%
metric_df
# Out:
#                            dimecoin_marketcap_usd  mooncoin_marketcap_usd  \
# datetime
# 2018-04-01 00:00:00+00:00              19092218.0              19357975.0
# 2018-04-02 00:00:00+00:00              15947398.0              27026867.0
# 2018-04-03 00:00:00+00:00              15436927.0              16840652.0
# 2018-04-04 00:00:00+00:00              14853732.0              16691652.0
# 2018-04-05 00:00:00+00:00              15835265.0              24790112.0
# ...                                           ...                     ...
# 2021-03-28 00:00:00+00:00               2915503.0                     NaN
# 2021-03-29 00:00:00+00:00               3871475.0                     NaN
# 2021-03-30 00:00:00+00:00               2892584.0                     NaN
# 2021-03-31 00:00:00+00:00               4554643.0                     NaN
# 2021-04-01 00:00:00+00:00               6157875.0                     NaN
#
#                            newyorkcoin_marketcap_usd  dogecoin_marketcap_usd  \
# datetime
# 2018-04-01 00:00:00+00:00                  9090861.0            3.094859e+08
# 2018-04-02 00:00:00+00:00                  9448815.0            3.184656e+08
# 2018-04-03 00:00:00+00:00                  9708156.0            3.392663e+08
# 2018-04-04 00:00:00+00:00                  9311793.0            3.154752e+08
# 2018-04-05 00:00:00+00:00                  9202639.0            3.090549e+08
# ...                                              ...                     ...
# 2021-03-28 00:00:00+00:00                        0.0            6.924336e+09
# 2021-03-29 00:00:00+00:00                        0.0            6.970631e+09
# 2021-03-30 00:00:00+00:00                        0.0            6.951867e+09
# 2021-03-31 00:00:00+00:00                        0.0            6.921249e+09
# 2021-04-01 00:00:00+00:00                        0.0            7.996434e+09
#
#                            experience-chain_marketcap_usd  \
# datetime
# 2018-04-01 00:00:00+00:00                             NaN
# 2018-04-02 00:00:00+00:00                             NaN
# 2018-04-03 00:00:00+00:00                             NaN
# 2018-04-04 00:00:00+00:00                             NaN
# 2018-04-05 00:00:00+00:00                             NaN
# ...                                                   ...
# 2021-03-28 00:00:00+00:00                       3656679.0
# 2021-03-29 00:00:00+00:00                       5381662.0
# 2021-03-30 00:00:00+00:00                       8307945.0
# 2021-03-31 00:00:00+00:00                       9933493.0
# 2021-04-01 00:00:00+00:00                      13751975.0
#
#                            telcoin_marketcap_usd  ripple_marketcap_usd  \
# datetime
# 2018-04-01 00:00:00+00:00             46279490.0          1.896401e+10
# 2018-04-02 00:00:00+00:00             46291371.0          1.957416e+10
# 2018-04-03 00:00:00+00:00             48724138.0          2.181646e+10
# 2018-04-04 00:00:00+00:00             42820121.0          1.961102e+10
# 2018-04-05 00:00:00+00:00             42458701.0          1.938310e+10
# ...                                          ...                   ...
# 2021-03-28 00:00:00+00:00            322454639.0          2.500653e+10
# 2021-03-29 00:00:00+00:00            377871797.0          2.581103e+10
# 2021-03-30 00:00:00+00:00            423911900.0          2.575325e+10
# 2021-03-31 00:00:00+00:00            394788172.0          2.606375e+10
# 2021-04-01 00:00:00+00:00            447160424.0          2.630268e+10
#
#                            vipstar-coin_marketcap_usd  \
# datetime
# 2018-04-01 00:00:00+00:00                         NaN
# 2018-04-02 00:00:00+00:00                         NaN
# 2018-04-03 00:00:00+00:00                         NaN
# 2018-04-04 00:00:00+00:00                         NaN
# 2018-04-05 00:00:00+00:00                         NaN
# ...                                               ...
# 2021-03-28 00:00:00+00:00                   2302844.0
# 2021-03-29 00:00:00+00:00                   2274717.0
# 2021-03-30 00:00:00+00:00                   2419222.0
# 2021-03-31 00:00:00+00:00                   2452077.0
# 2021-04-01 00:00:00+00:00                   2339653.0
#
#                            microbitcoin_marketcap_usd  \
# datetime
# 2018-04-01 00:00:00+00:00                         NaN
# 2018-04-02 00:00:00+00:00                         NaN
# 2018-04-03 00:00:00+00:00                         NaN
# 2018-04-04 00:00:00+00:00                         NaN
# 2018-04-05 00:00:00+00:00                         NaN
# ...                                               ...
# 2021-03-28 00:00:00+00:00                   1131859.0
# 2021-03-29 00:00:00+00:00                   1161039.0
# 2021-03-30 00:00:00+00:00                   1825373.0
# 2021-03-31 00:00:00+00:00                   1848121.0
# 2021-04-01 00:00:00+00:00                   1897400.0
#
#                            inflationcoin_marketcap_usd  ...  \
# datetime                                                ...
# 2018-04-01 00:00:00+00:00                    1751622.0  ...
# 2018-04-02 00:00:00+00:00                    1277756.0  ...
# 2018-04-03 00:00:00+00:00                    2312558.0  ...
# 2018-04-04 00:00:00+00:00                    2538962.0  ...
# 2018-04-05 00:00:00+00:00                    2598683.0  ...
# ...                                                ...  ...
# 2021-03-28 00:00:00+00:00                          0.0  ...
# 2021-03-29 00:00:00+00:00                          0.0  ...
# 2021-03-30 00:00:00+00:00                          0.0  ...
# 2021-03-31 00:00:00+00:00                          0.0  ...
# 2021-04-01 00:00:00+00:00                          0.0  ...
#
#                            lightpaycoin_marketcap_usd  axe_marketcap_usd  \
# datetime
# 2018-04-01 00:00:00+00:00                         NaN                NaN
# 2018-04-02 00:00:00+00:00                         NaN                NaN
# 2018-04-03 00:00:00+00:00                         NaN                NaN
# 2018-04-04 00:00:00+00:00                         NaN                NaN
# 2018-04-05 00:00:00+00:00                         NaN                NaN
# ...                                               ...                ...
# 2021-03-28 00:00:00+00:00                         NaN          1670378.0
# 2021-03-29 00:00:00+00:00                         NaN          1970512.0
# 2021-03-30 00:00:00+00:00                         NaN          1567737.0
# 2021-03-31 00:00:00+00:00                         NaN          1540362.0
# 2021-04-01 00:00:00+00:00                         NaN          1275330.0
#
#                            buysell_marketcap_usd  stakinglab_marketcap_usd  \
# datetime
# 2018-04-01 00:00:00+00:00                    NaN                       NaN
# 2018-04-02 00:00:00+00:00                    NaN                       NaN
# 2018-04-03 00:00:00+00:00                    NaN                       NaN
# 2018-04-04 00:00:00+00:00                    NaN                       NaN
# 2018-04-05 00:00:00+00:00                    NaN                       NaN
# ...                                          ...                       ...
# 2021-03-28 00:00:00+00:00                    0.0                    2267.0
# 2021-03-29 00:00:00+00:00                    0.0                    2340.0
# 2021-03-30 00:00:00+00:00                    0.0                    2626.0
# 2021-03-31 00:00:00+00:00                    0.0                    2626.0
# 2021-04-01 00:00:00+00:00                    0.0                    2155.0
#
#                            novacoin_marketcap_usd  \
# datetime
# 2018-04-01 00:00:00+00:00               6435092.0
# 2018-04-02 00:00:00+00:00               6574682.0
# 2018-04-03 00:00:00+00:00               6832435.0
# 2018-04-04 00:00:00+00:00               6404479.0
# 2018-04-05 00:00:00+00:00               6485918.0
# ...                                           ...
# 2021-03-28 00:00:00+00:00                     NaN
# 2021-03-29 00:00:00+00:00                     NaN
# 2021-03-30 00:00:00+00:00                     NaN
# 2021-03-31 00:00:00+00:00                     NaN
# 2021-04-01 00:00:00+00:00                     NaN
#
#                            bitcoin-rhodium_marketcap_usd  \
# datetime
# 2018-04-01 00:00:00+00:00                            NaN
# 2018-04-02 00:00:00+00:00                            NaN
# 2018-04-03 00:00:00+00:00                            NaN
# 2018-04-04 00:00:00+00:00                            NaN
# 2018-04-05 00:00:00+00:00                            NaN
# ...                                                  ...
# 2021-03-28 00:00:00+00:00                      6184725.0
# 2021-03-29 00:00:00+00:00                      8598011.0
# 2021-03-30 00:00:00+00:00                     10536552.0
# 2021-03-31 00:00:00+00:00                      8718256.0
# 2021-04-01 00:00:00+00:00                      8266949.0
#
#                            white-standard_marketcap_usd  \
# datetime
# 2018-04-01 00:00:00+00:00                           NaN
# 2018-04-02 00:00:00+00:00                           NaN
# 2018-04-03 00:00:00+00:00                           NaN
# 2018-04-04 00:00:00+00:00                           NaN
# 2018-04-05 00:00:00+00:00                           NaN
# ...                                                 ...
# 2021-03-28 00:00:00+00:00                           NaN
# 2021-03-29 00:00:00+00:00                           NaN
# 2021-03-30 00:00:00+00:00                           NaN
# 2021-03-31 00:00:00+00:00                           NaN
# 2021-04-01 00:00:00+00:00                           NaN
#
#                            parallelcoin_marketcap_usd  \
# datetime
# 2018-04-01 00:00:00+00:00                    163345.0
# 2018-04-02 00:00:00+00:00                    128673.0
# 2018-04-03 00:00:00+00:00                    141463.0
# 2018-04-04 00:00:00+00:00                    117282.0
# 2018-04-05 00:00:00+00:00                    168395.0
# ...                                               ...
# 2021-03-28 00:00:00+00:00                    149550.0
# 2021-03-29 00:00:00+00:00                    154484.0
# 2021-03-30 00:00:00+00:00                    169195.0
# 2021-03-31 00:00:00+00:00                    219369.0
# 2021-04-01 00:00:00+00:00                    187696.0
#
#                            unobtanium_marketcap_usd  amoveo_marketcap_usd
# datetime
# 2018-04-01 00:00:00+00:00                25740230.0                   NaN
# 2018-04-02 00:00:00+00:00                25658509.0                   NaN
# 2018-04-03 00:00:00+00:00                27842425.0                   NaN
# 2018-04-04 00:00:00+00:00                25879422.0                   NaN
# 2018-04-05 00:00:00+00:00                25654005.0                   NaN
# ...                                             ...                   ...
# 2021-03-28 00:00:00+00:00                       0.0                   0.0
# 2021-03-29 00:00:00+00:00                       0.0                   0.0
# 2021-03-30 00:00:00+00:00                       0.0                   0.0
# 2021-03-31 00:00:00+00:00                       0.0                   0.0
# 2021-04-01 00:00:00+00:00                       0.0                   0.0
#
# [1097 rows x 139 columns]
