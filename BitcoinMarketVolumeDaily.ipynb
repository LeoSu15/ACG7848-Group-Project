# %%
import pandas as pd

# %%
pip install sanpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade sanpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already up-to-date: sanpy in ./.local/lib/python3.8/site-packages (0.8.6)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import san
san.ApiConfig.api_key = '6eb6sv5da6x7hzg7_wln6zfn4hrgvdtws'
san.get("projects/all")
# Out:
#          marketSegment             name             slug ticker  \
# 0             Platform   Color Platform   color-platform    CLR
# 1             Ethereum          Enecuum          enecuum    ENQ
# 2     Interoperability           Cosmos           cosmos   ATOM
# 3             Ethereum         ZeuxCoin         zeuxcoin    ZUC
# 4               Gaming             Seed             seed   SEED
# ...                ...              ...              ...    ...
# 1938          Ethereum            Crust            crust    CRU
# 1939          Ethereum  PieDAO DOUGH v2  piedao-dough-v2  DOUGH
# 1940            Oracle         SmartKey         smartkey   SKEY
# 1941           Privacy             Firo            zcoin    XZC
# 1942          Ethereum  Crypto.com Coin  crypto-com-coin    CRO
#
#             totalSupply
# 0             350000000
# 1          193681682.38
# 2      269787743.664671
# 3             750000000
# 4                  None
# ...                 ...
# ...

# %%
import matplotlib.pyplot as plt

# %%
BitcoinDaily = san.get("ohlcv/bitcoin", from_date="2018-04-01", to_date="2021-04-01")

# %%
BitcoinDaily
# Out:
#                            openPriceUsd  closePriceUsd  highPriceUsd  \
# datetime
# 2018-04-01 00:00:00+00:00   7003.060000    6844.230000   7060.950000
# 2018-04-02 00:00:00+00:00   6844.860000    7083.800000   7135.470000
# 2018-04-03 00:00:00+00:00   7102.260000    7456.110000   7530.940000
# 2018-04-04 00:00:00+00:00   7456.410000    6853.840000   7469.880000
# 2018-04-05 00:00:00+00:00   6848.650000    6811.470000   6933.820000
# ...                                 ...            ...           ...
# 2021-03-28 00:00:00+00:00  55985.195932   55950.745774  56605.704062
# 2021-03-29 00:00:00+00:00  55959.205099   57750.199871  58335.000916
# 2021-03-30 00:00:00+00:00  57727.859968   58917.693045  59447.224031
# 2021-03-31 00:00:00+00:00  58969.000845   58918.832714  59898.378041
# 2021-04-01 00:00:00+00:00  59024.496076   59095.807978  59586.072249
#
#                             lowPriceUsd        volume     marketcap
# datetime
# ...

# %%
for col in BitcoinDaily.columns:
    print(col)
# Out:
# openPriceUsd
# closePriceUsd
# highPriceUsd
# lowPriceUsd
# volume
# marketcap

# %%
del BitcoinDaily["openPriceUsd"]
del BitcoinDaily["closePriceUsd"]
del BitcoinDaily["highPriceUsd"]
del BitcoinDaily["lowPriceUsd"]
del BitcoinDaily["marketcap"]

# %%
#Bitcoin Daily Volume from 2018-04-01 <-> 2021-04-01
BitcoinDaily.head(20)
# Out:
#                                  volume
# datetime
# 2018-04-01 00:00:00+00:00  4.532100e+09
# 2018-04-02 00:00:00+00:00  4.333440e+09
# 2018-04-03 00:00:00+00:00  5.499700e+09
# 2018-04-04 00:00:00+00:00  4.936000e+09
# 2018-04-05 00:00:00+00:00  5.639320e+09
# ...                                 ...
# 2021-03-28 00:00:00+00:00  4.768658e+10
# 2021-03-29 00:00:00+00:00  5.762559e+10
# 2021-03-30 00:00:00+00:00  5.441412e+10
# 2021-03-31 00:00:00+00:00  6.552083e+10
# 2021-04-01 00:00:00+00:00  6.166916e+10
#
# [1097 rows x 1 columns]
